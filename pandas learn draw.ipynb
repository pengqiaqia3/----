# %%
import pandas as pd
import numpy as np
import matplotlib
s = pd.Series(np.random.randn(10),index= np.arange(0,100,10))
s.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(10,4).cumsum(0),index=np.arange(0,100,10),columns=['A','B','C','D'])
df
# Out:
#            A         B         C         D
# 0   0.250701 -0.533276 -0.587825 -0.095026
# 10 -0.185858 -1.540900 -1.136278 -0.441768
# 20 -1.141371 -3.056049 -1.028341 -0.069314
# 30 -1.812951 -3.529832 -1.970230 -0.707378
# 40 -2.833793 -5.052865 -1.285188  1.118740
# 50 -2.608024 -5.694316 -0.954714  0.778345
# 60 -3.865888 -6.183780 -1.948640  2.137208
# 70 -5.572205 -6.981881 -1.648371  3.546147
# 80 -4.840722 -7.613292 -1.455935  3.645795
# 90 -5.504831 -8.033328 -1.783776  4.227342

# %%
df.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt    
data = pd.Series(np.random.randn(16),index=list('abcdefghijklmnop'))
fig,axes = plt.subplots(2,1)   #绘图的位置 两行一列 两张图
data.plot(ax=axes[0],kind='bar')    # 指定坐标和柱状图样式
data.plot(ax=axes[1],kind='barh')
# Out:
# <Axes: >

# %%
df = pd.DataFrame(data =np.random.rand(6,4),
                  index=['one','tow','three','four','five','six'],
                  columns=pd.Index(['A','B','C','D']))
df
# Out:
#               A         B         C         D
# one    0.561298  0.194426  0.597773  0.590794
# tow    0.008001  0.747410  0.506858  0.188597
# three  0.974076  0.353967  0.262009  0.331848
# four   0.997503  0.914690  0.923290  0.602348
# five   0.757708  0.989677  0.010513  0.842411
# six    0.854123  0.129199  0.608322  0.838437

# %%
df.plot(kind='bar',title='Genus')
# Out:
# <Axes: title={'center': 'Genus'}>

# %%
titanic = pd.read_csv("titanic_train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.Age.plot(kind='hist',bins=50)   # x轴划分为50个区间 画出每个区间的人数
# Out:
# <Axes: ylabel='Frequency'>

# %%
data = titanic[['Age','Fare']]
data
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
data.plot.scatter('Age','Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
pd.plotting.scatter_matrix(data,color='g',alpha=0.3)   # 散点图 每一项两两之间的散点图
# Out:
# array([[<Axes: xlabel='Age', ylabel='Age'>,
#         <Axes: xlabel='Fare', ylabel='Age'>],
#        [<Axes: xlabel='Age', ylabel='Fare'>,
#         <Axes: xlabel='Fare', ylabel='Fare'>]], dtype=object)
